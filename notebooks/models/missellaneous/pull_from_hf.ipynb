# %%
import json
from datasets import load_dataset
ds = load_dataset("cesarali/lenuzza-2016")
# Out:
# README.md:   0%|          | 0.00/810 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/30.0k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/18 [00:00<?, ? examples/s]

# %%
type(ds["train"])
# Out:
# datasets.arrow_dataset.Dataset

# %%
ds["train"][0]
# Out:
# {'context': [{'dosing': [0.005],
#    'dosing_name': ['memantine'],
#    'dosing_times': [0.0],
#    'dosing_type': ['oral'],
#    'name_id': 'memantine_3',
#    'observation_times': [1.5, 3.0, 8.0, 12.0, 24.0, 48.0, 72.0, 168.0],
#    'observations': [1.8246728000000005e-07,
#     5.957865000000001e-06,
#     5.013268000000001e-06,
#     5.572757200000001e-06,
#     4.535133400000001e-06,
#     4.218433e-06,
#     1.7894546000000002e-06,
#     1.3137133000000002e-07],
#    'remaining': [],
#    'remaining_times': []},
#   {'dosing': [0.005],
#    'dosing_name': ['memantine'],
#    'dosing_times': [0.0],
#    'dosing_type': ['oral'],
#    'name_id': 'memantine_4',
#    'observation_times': [1.5, 3.0, 8.0, 12.0, 24.0, 48.0, 72.0, 168.0],
#    'observations': [2.2672625000000002e-07,
#     6.734340000000001e-06,
#     5.859163000000001e-06,
#     6.092060600000001e-06,
#     4.902836300000001e-06,
#     3.1755120000000003e-06,
#     2.9048233000000004e-06,
# ...
