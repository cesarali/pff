# %%
import os
from pff.training.basic_experiment import BasicLightningExperiment

# %%
experiment = BasicLightningExperiment(experiment_key="14ed6f5557964dd69d5adda52e6423a0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 experiment = BasicLightningExperiment(experiment_key="14ed6f5557964dd69d5adda52e6423a0")
#
# File ~/Pharma/pff/pff/training/basic_experiment.py:119, in BasicLightningExperiment.__init__(self, model_config, hf_model_id, experiment_key, map_location, checkpoint_type, comet_key, train_new, devices, results_dir, strategy, strict)
#     116     self._setup_from_hf(hf_model_id)
#     117 elif experiment_key is not None:
#     118     # 2.1) old logger old weights set up for resume
# --> 119     model_config = self._setup_from_experiment_key(comet_key or comet_key,
#     120                                                    experiment_key,
#     121                                                    checkpoint_type,
#     122                                                    results_dir,
# ...
